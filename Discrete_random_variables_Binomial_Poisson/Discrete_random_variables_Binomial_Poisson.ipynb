# %% [markdown]
# ### 1. Вероятность того, что стрелок попадет в мишень, выстрелив один раз, равна 0.8. Стрелок выстрелил 100 раз. Найдите вероятность того, что стрелок попадет в цель ровно 85 раз.

# %% [markdown]
# ### Решение:
# ### $$P_n(X=k) = C_n^k p^k q^{n-k}$$
# ### $$p=0.8$$
# ### $$q=1-p \Rightarrow q=0.2$$
# ### $$P_{100}(85) = C_{100}^{85} 0.8^{85} 0.2^{15}= \frac{100!}{85!(100-85)!}0.8^{85} 0.2^{15}\approx0,048$$

# %% [markdown]
# ### 2. Вероятность того, что лампочка перегорит в течение первого дня эксплуатации, равна 0.0004. В жилом комплексе после ремонта в один день включили 5000 новых лампочек. Какова вероятность, что ни одна из них не перегорит в первый день? Какова вероятность, что перегорят ровно две?

# %% [markdown]
# ### Решение:
# ### $$P_m \approx \frac{\lambda^m}{m!}e^{-\lambda}$$
# ### $$m=0,n=5000,\lambda=n \cdot p \approx 5000 \cdot 0.0004 = 2$$
# ### $$P_0 \approx \frac{2^0}{0!}e^{-2} \approx 0.1353$$
# ### $$m=2,n=5000,\lambda=n \cdot p \approx 5000 \cdot 0.0004 = 2$$
# ### $$P_2 \approx \frac{2^2}{2!}e^{-2} \approx 0.2706$$

# %% [markdown]
# ### 3. Монету подбросили 144 раза. Какова вероятность, что орел выпадет ровно 70 раз?

# %% [markdown]
# ### Решение
# ### $$P_n(X=k) = C_n^k p^k q^{n-k}$$
# ### $p=\frac{1}{2}$ - верятность выпадения орла
# ### $$P_{144}(70) = C_{144}^{70} 0.5^{70} 0.5^{74}= \frac{144!}{70!(74!)!}0.5^{70} 0.5^{74}\approx0,0628$$

# %% [markdown]
# ### 4. В первом ящике находится 10 мячей, из которых 7 - белые. Во втором ящике - 11 мячей, из которых 9 белых. Из каждого ящика вытаскивают случайным образом по два мяча. Какова вероятность того, что все мячи белые? Какова вероятность того, что ровно два мяча белые? Какова вероятность того, что хотя бы один мяч белый?

# %% [markdown]
# ### Решение
# #### Вероятность того, что все вытащенные мячи будут белые:
# #### $$P=\frac{C_{7}^{2}}{C_{10}^{2}}\cdot\frac{C_{9}^{2}}{C_{11}^{2}} = \frac{21}{45}\cdot \frac{36}{55} \approx 0,3054 $$
# #### Вероятность того, что , будут вытащены ровно 2 белых мяча :
# #### $$P=\frac{C_{7}^{2}}{C_{10}^{2}}\cdot\frac{C_{2}^{2}}{C_{11}^{2}} + \frac{C_{3}^{2}}{C_{10}^{2}}\cdot\frac{C_{9}^{2}}{C_{11}^{2}} + \frac{C_{7}^{1}\cdot C_{3}^1}{C_{10}^{2}}\cdot\frac{C_{9}^{1}\cdot C_{2}^1}{C_{11}^{2}}= \frac{21}{45}\cdot \frac{1}{55} + \frac{3}{45}\cdot \frac{36}{55} + \frac{7\cdot 3}{45}\cdot \frac{9\cdot2}{55} \approx 0,2048 $$
# #### Вероятность того, что , будет вытащен хотя бы дин белый шар:
# #### $$P=1 - P_{black} =1 \frac{C_{3}^{2}}{C_{10}^{2}}\cdot\frac{C_{2}^{2}}{C_{11}^{2}} =1 - \frac{1}{15}\cdot \frac{1}{55} \approx 0,9987 $$
